# %% [markdown]
# #matplotlib library

# %%
from PIL import Image

import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,4,18],[1,7,14,6],'go')
plt.axis((0, 22, 0, 13))
# Out:
# (0.0, 22.0, 0.0, 13.0)

# %%
t=np.arange(0,5,0.5)
t
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5])

# %%
plt.plot(t,t,'b--',t,t**2,'g^',t,t**4,'r-.')
